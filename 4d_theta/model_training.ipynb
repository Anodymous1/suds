# %% [markdown]
# #  Model Training

# %% [markdown]
# ## Generate data

# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"     # agama
os.environ["MKL_NUM_THREADS"] = "1"     # numpy, scipy
os.environ["OPENBLAS_NUM_THREADS"] = "1"    # numpy
os.environ["NUMEXPR_NUM_THREADS"] = "1"     # pandas

import agama
import torch 
import numpy as np
from scipy import integrate
# from scipy.stats import wasserstein_distance_nd
from astropy import units as u

from sbi.utils import BoxUniform

from sbi.inference import SNLE, simulate_for_sbi, prepare_for_sbi


from sbi.utils import likelihood_nn

from sklearn.metrics import mean_squared_error, r2_score

import pandas as pd
import pickle
import matplotlib.pyplot as plt
from python_scripts.galaxy_generation import generate_galaxy_multiple
from python_scripts.prior_generation import generate_prior
from python_scripts.standardization import standardize

from wasserstein_distance_nd import wasserstein_distance_nd
import corner

torch.set_num_threads(4)

# %%
# set agama unit to be in Msun, kpc, km/s
agama.setUnits(mass=1 * u.Msun, length=1*u.kpc, velocity=1 * u.km /u.s)

# %% [markdown]
# ## Training

# %%
agama.setRandomSeed(13)
torch.manual_seed(13)
np.random.seed(13)

# %% [markdown]
# ### Generating data

# %%
prior = generate_prior()
simulator_sbi, prior_sbi = prepare_for_sbi(generate_galaxy_multiple, prior)

# %%
#. Generate Training Data
theta_train, x_train = simulate_for_sbi(
    simulator_sbi, prior_sbi, num_simulations=1000, num_workers=1
)
x_train = x_train.squeeze()
# Out:
# Running 1000 simulations.:   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 #. Generate Training Data
# ----> 2 theta_train, x_train = simulate_for_sbi(
#       3     simulator_sbi, prior_sbi, num_simulations=1000, num_workers=1
#       4 )
#       5 x_train = x_train.squeeze()
#
# File /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/sbi/inference/base.py:495, in simulate_for_sbi(simulator, proposal, num_simulations, num_workers, simulation_batch_size, show_progress_bar)
#     466 r"""Returns ($\theta, x$) pairs obtained from sampling the proposal and simulating.
#     467
#     468 This function performs two steps:
#    (...)
#     490 Returns: Sampled parameters $\theta$ and simulation-outputs $x$.
#     491 """
#     493 theta = proposal.sample((num_simulations,))
# ...

# %% [markdown]
# #### Generating 10000 data then saving to csv

# %%
prior = generate_prior()

# %%
theta = prior.sample((10000,))
df = pd.DataFrame(np.repeat(theta, 100, axis=0))
df.to_csv("./data/training_theta.csv", index=False, header=False)

# %%
x = generate_galaxy_multiple(theta, 100).numpy()
out = x.reshape(x.shape[0] * x.shape[1], x.shape[2])
df = pd.DataFrame(out)

df.to_csv("./data/training_x.csv", index=False, header=False)

# %% [markdown]
# #### Generating 10k galaxies, 10 stars

# %%
df = np.array(pd.read_csv("./data/training_x(100).csv", header=None))
df= df.reshape((10000, 100, 6))
df = df[:, :10, :]
df = pd.DataFrame(df.reshape((100000, 6)))
df.to_csv("./data/training_x(10).csv", index=False, header=False)

# %%
df = np.array(pd.read_csv("./data/training_theta(100).csv", header=None))
df= df.reshape((10000, 100, 4))
df = df[:, :10, :]
df = pd.DataFrame(df.reshape((100000, 4)))
df.to_csv("./data/training_theta(10).csv", index=False, header=False)

# %% [markdown]
# #### Generating 1 galaxy, 1k stars

# %%
theta = torch.tensor(np.array([[7, 0, 0, 0.2]]))
df = pd.DataFrame(generate_galaxy_multiple(theta, 1000).squeeze())
df.to_csv("./model 3/mass_density")
# Out:
# torch.Size([1000, 6])

# %% [markdown]
# #### Poisson distribution

# %%
prior = generate_prior()
thetas = prior.sample((10000,))

n_list = []
output_x = []

for row in thetas:
    r = row.reshape((1,4))
    n = np.random.poisson(100)
    n_list.append(n)
    
    xs = generate_galaxy_multiple(r, n_stars=n)
    output_x.append(xs)
    
theta = torch.repeat_interleave(thetas, torch.tensor(n_list), dim=0)
x = torch.cat(output_x, dim=1).squeeze()

# %%
pd.DataFrame(theta).to_csv("./data/training_theta(poisson).csv", header=False, index=False)
pd.DataFrame(x).to_csv("./data/training_x(poisson).csv", header=False, index=False)

# %% [markdown]
# #### Test samples

# %%
prior = generate_prior()
thetas = prior.sample((1000,))

n_list = []
output_x = []

for row in thetas:
    r = row.reshape((1,4))
    n = np.random.poisson(100)
    n_list.append(n)
    
    xs = generate_galaxy_multiple(r, n_stars=n)
    output_x.append(xs)
    
theta = torch.repeat_interleave(thetas, torch.tensor(n_list), dim=0)
x = torch.cat(output_x, dim=1).squeeze()
    
pd.DataFrame(theta).to_csv("./data/test_theta.csv", header=False, index=False)
pd.DataFrame(x).to_csv("./data/test_x.csv", header=False, index=False)

# %% [markdown]
# ### Train the model

# %% [markdown]
# #### Single star per galaxy

# %%
theta_train = torch.from_numpy(np.array(pd.read_csv("./data/training_theta(poisson).csv", header=None))).float()
x_train = torch.from_numpy(np.array(pd.read_csv("./data/training_x(poisson).csv", header=None))).float()

# %%
torch.set_num_threads(4)
prior_sbi = generate_prior()

density_estimator =likelihood_nn(model="maf", 
                                 hidden_features = 97,
                                 num_transforms = 10,
                                 num_bins = 10)

inference = SNLE(prior=prior_sbi, density_estimator=density_estimator)
inference.append_simulations(theta_train, x_train)
arg = {
        "training_batch_size": 2048,
        "learning_rate": 0.00337562831493679,
        "validation_fraction": 0.1,
        "stop_after_epochs": 10,
        "max_num_epochs": 2**31 - 1,
        "clip_max_norm": 5.0,
        "resume_training": False,
        "discard_prior_samples": False,
        "retrain_from_scratch": False,
        "show_train_summary": True,
        # "dataloader_kwargs": {"num_workers": 2, 
        #                         "persistent_workers": True}
}

likelihood_estimator = inference.train(**arg)

# lr: 0.001347, tbs: 512
# Out:
#  Neural network successfully converged after 23 epochs.
#         -------------------------
#         ||||| ROUND 1 STATS |||||:
#         -------------------------
#         Epochs trained: 23
#         Best validation performance: -7.6482
#         -------------------------

# %%
inference._summary["best_validation_log_prob"]
# Out:
# [-8.988222122192383]

# %% [markdown]
# ### Pickle

# %%
posterior = inference.build_posterior(likelihood_estimator, mcmc_method="slice_np_vectorized")

with open("./model/posterior.pkl", "wb") as handle:
    pickle.dump(posterior, handle)

# %%
with open("./model/likelihood_estimator_maf(poisson).pkl", "wb") as handle:
    pickle.dump(likelihood_estimator, handle)

# %%
with open("./model/inference_maf(poisson).pkl", "wb") as handle:
    pickle.dump(inference, handle)
# Out:
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/sbi/inference/base.py:429: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   warn(

# %%
with open('./model/posterior.pkl', 'rb') as file:
    # Load the object from the file
    posterior = pickle.load(file)

# %% [markdown]
# ### Hyperparameter tuning

# %%
import optuna

# %%
# outdated

def objective(trial):
        
    learning_rate = trial.suggest_float("learning_rate", 1e-5, 1e-2, log=True)
    training_batch_size = trial.suggest_categorical("training_batch_size", [32, 64, 128, 256, 512, 1024, 2048])
    
    
    theta_train = torch.from_numpy(np.array(pd.read_csv("./data/training_theta.csv", header=None))).float()
    x_train = torch.from_numpy(np.array(pd.read_csv("./data/training_x.csv", header=None))).float() 
    
    prior_sbi = generate_prior()
    inference = SNLE(prior=prior_sbi)
    inference.append_simulations(theta_train, x_train)
    
    likelihood_estimator = inference.train(learning_rate = learning_rate,
                                           training_batch_size = training_batch_size,
                                           stop_after_epochs = 10,
    )
    
    return inference._summary["best_validation_log_prob"][0]

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=2)

import pickle
with open("./model/tune.pkl", "wb") as handle:
    pickle.dump(study, handle)
    
print(study.best_params)
# Out:
# [I 2026-05-19 09:25:52,851] A new study created in memory with name: no-name-ca9aa964-5828-4182-bfd7-5129bfa15e72
#  Training neural network. Epochs trained: 109
# [I 2026-05-19 09:41:45,440] Trial 0 finished with value: -7.2913370289522055 and parameters: {'learning_rate': 0.00046936482650969613, 'training_batch_size': 425, 'stop_after_epochs': 20}. Best is trial 0 with value: -7.2913370289522055.
#  Training neural network. Epochs trained: 160110 epochs.
# [I 2026-05-19 10:04:58,854] Trial 1 finished with value: -8.581448269873551 and parameters: {'learning_rate': 6.218574263473771e-05, 'training_batch_size': 388, 'stop_after_epochs': 20}. Best is trial 0 with value: -7.2913370289522055.
#  Neural network successfully converged after 161 epochs.

# %%
with open('./model/inference(poisson).pkl', 'rb') as file:
    # Load the object from the file
    k = pickle.load(file)

# %%
k._summary["best_validation_log_prob"]
# Out:
# [-7.589549103761331]

# %% [markdown]
# Optuna results

# %%
with open('./model_11/tune_model_11_str_200k.pkl', 'rb') as file:
    # Load the object from the file
    result = pickle.load(file)

# %%
# import optuna
# import matplotlib.pyplot as plt
# optuna.visualization.plot_optimization_history(result)

# %%
result.trials[15]
# Out:
# FrozenTrial(number=15, state=<TrialState.COMPLETE: 1>, values=[1.9572709095783722], datetime_start=datetime.datetime(2026, 6, 17, 19, 3, 3, 499568), datetime_complete=datetime.datetime(2026, 6, 17, 19, 15, 6, 317351), params={'learning_rate': 0.0026252327017341126, 'training_batch_size': 512, 'model': 'nsf', 'hidden_features': 70, 'num_transforms': 4, 'num_bins': 10}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': FloatDistribution(high=0.01, log=True, low=1e-05, step=None), 'training_batch_size': CategoricalDistribution(choices=(256, 512, 1024, 2048, 4096)), 'model': CategoricalDistribution(choices=('maf', 'nsf')), 'hidden_features': IntDistribution(high=128, log=False, low=32, step=1), 'num_transforms': IntDistribution(high=8, log=False, low=3, step=1), 'num_bins': IntDistribution(high=12, log=False, low=4, step=1)}, trial_id=15, value=None)

# %% [markdown]
# ## MCMC

# %% [markdown]
# #### MCMCPosterior

# %%
from sbi.inference import likelihood_estimator_based_potential, MCMCPosterior

# %%
import gc
def generate_samples(x_o, likelihood_estimator, prior, n_samples):
    """
    generate sample for single observed x (perhaps with multiple stars, but generated from same theta)

    - x_o: observed universe
    - n_samples: number of samples to generate
    """
    potential_fn, parameter_transform = likelihood_estimator_based_potential(
    likelihood_estimator, prior, x_o
)
    posterior = MCMCPosterior(
    potential_fn, proposal=prior, 
    theta_transform=parameter_transform, 
    warmup_steps=200,
    num_chains=8,
    num_workers= 4,
    method = "slice_np_vectorized"
    )

    samples = posterior.sample((n_samples,))

    del posterior
    del potential_fn
    del parameter_transform
    
    gc.collect()
    
    return samples

# %%
with open('./model/likelihood_estimator(poisson_d_20k).pkl', 'rb') as file:
    # Load the object from the file
    likelihood_estimator = pickle.load(file)

# %%
test_theta_raw = np.array(pd.read_csv("./data/test_theta.csv", header=None))
test_x_raw = np.array(pd.read_csv("./data/test_x.csv", header=None))

# %%
test_theta, index = np.unique(test_theta_raw, axis=0, return_index=True)

index = np.sort(index)

test_x = np.split(test_x_raw, index, axis=0)[1:]

# %% [markdown]
# Parallel

# %%
from joblib import Parallel, delayed

torch.set_num_threads(1)

results = Parallel(n_jobs=4)(
    delayed(generate_samples)(x_o, likelihood_estimator, prior, 1000) for x_o in test_x
)

samples = np.array(results)
# Out:
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/sbi/utils/sbiutils.py:316: UserWarning: An x with a batch size of 99 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   warnings.warn(
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/sbi/utils/sbiutils.py:316: UserWarning: An x with a batch size of 104 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   warnings.warn(
# Generating 8 MCMC inits with 4
# ...

# %% [markdown]
# Single

# %%
prior = generate_prior()
generate_samples(test_x[0][:10], likelihood_estimator, prior, 100)
# Out:
# work1
# work2
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/sbi/utils/sbiutils.py:316: UserWarning: An x with a batch size of 10 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   warnings.warn(
# Generating 8 MCMC inits with 4
#                          workers.:   0%|          | 0/8 [00:00<?, ?it/s]
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ...

# %%
test_theta[0]
# Out:
# array([5.0012994 , 0.05278873, 1.0659394 , 0.290999  ])

# %% [markdown]
# #### Posterior

# %%
test_theta_raw = np.array(pd.read_csv("./data/test_theta.csv", header=None))
test_x_raw = np.array(pd.read_csv("./data/test_x.csv", header=None))

test_theta, index = np.unique(test_theta_raw, axis=0, return_index=True)

index = np.sort(index)

test_x = np.split(test_x_raw, index, axis=0)[1:]

# %%
with open('./model/likelihood_estimator(poisson_d_20k).pkl', 'rb') as file:
    # Load the object from the file
    likelihood_estimator = pickle.load(file)
    

with open('./model/inference(poisson_d_20k).pkl', 'rb') as file:
    # Load the object from the file
    inference = pickle.load(file)

# %%
torch.set_num_threads(1)
import os
os.environ["OMP_NUM_THREADS"] = "1"

posterior = inference.build_posterior(
                                      mcmc_method="slice_np_vectorized", 
                                      mcmc_parameters={"warmup_steps":200,
                                                        "num_chains":32,
                                                        "num_workers": 4,
                                                        "init_strategy": "sir"})

# %%
samples = posterior.sample_batched((1000,), x=test_x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 samples = posterior.sample_batched((1000,), x=test_x[:2])
#
# AttributeError: 'MCMCPosterior' object has no attribute 'sample_batched'

# %%
print(np.median(samples, axis=0))
print(test_theta[0])
# Out:
# [ 6.8912916  -0.21873423  0.39861274  0.39733654]
# [5.0012994  0.05278873 1.0659394  0.290999  ]

# %%
torch.set_num_threads(1)
posterior = inference.build_posterior(mcmc_method='slice_np_vectorized')
samples = posterior.sample((1000,), x=test_x[0]) # 1000 posterior samples
# Out:
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/sbi/utils/sbiutils.py:316: UserWarning: An x with a batch size of 104 was passed. It will be interpreted as a batch of independent and identically
#             distributed data X={x_1, ..., x_n}, i.e., data generated based on the
#             same underlying (unknown) parameter. The resulting posterior will be with
#             respect to entire batch, i.e,. p(theta | X).
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 torch.set_num_threads(1)
#       2 posterior = inference.build_posterior(likelihood_estimator, mcmc_method='slice_np_vectorized')
# ----> 3 samples = posterior.sample((1000,), x=test_x[0])
#
# ...

# %%
test_x[0][0].shape
# Out:
# (6,)

# %%
posterior.log_prob(test_theta[0].astype(np.float32), x=test_x[0][0])
# Out:
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/sbi/inference/posteriors/mcmc_posterior.py:172: UserWarning: `.log_prob()` is deprecated for methods that can only evaluate the
#             log-probability up to a normalizing constant. Use `.potential()` instead.
#   warn(
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/sbi/inference/posteriors/mcmc_posterior.py:176: UserWarning: The log-probability is unnormalized!
#   warn("The log-probability is unnormalized!")
# tensor([-10.0047])

# %% [markdown]
# ## Evaluating model performance

# %% [markdown]
# #### Evaluate

# %%
def evaluate_model(theta, medians):
    """
    Evaluates model for theta with galaxies with same number of star
    """
    
    for i in range(4):
        mse = mean_squared_error(theta[:,i], medians[:,i])
        r2 = r2_score(theta[:,i], medians[:,i])
        print(f"MSE for {i}th entry is {mse}")
        print(f"R^2 for {i}th entry is {r2}")
        print()

# %% [markdown]
# #### Random stared

# %%
with open("./model_14/samples_model_14.pkl", "rb") as file:
    post = pickle.load(file)
    
medians = np.zeros((100,4))
for i, th in enumerate(post):
    medians[i,:] = np.median(th, axis=0)

# %%
test_theta_raw = np.array(pd.read_csv("./model_11/test_theta.csv", header=None))
_, index= np.unique(test_theta_raw, axis=0, return_index=True)

index.sort()

test_theta = test_theta_raw[index][:100]

# %%
evaluate_model(test_theta, medians)
# Out:
# MSE for 0th entry is 0.14817225614046847
# R^2 for 0th entry is 0.7998856681655999
#
# MSE for 1th entry is 0.024807284429140184
# R^2 for 1th entry is 0.8763462442036516
#
# MSE for 2th entry is 0.18606910202241458
# R^2 for 2th entry is 0.7147066913843187
#
# MSE for 3th entry is 0.03969231254361893
# R^2 for 3th entry is 0.28416276627547354

# %%
np.median(post[99], axis=0)
# Out:
# array([ 6.405495  ,  0.23014194, -0.3323327 ,  0.5995596 ], dtype=float32)

# %% [markdown]
# ## Graphing Performance of model

# %% [markdown]
# ### Line graph

# %% [markdown]
# x and y are supposed to be MCMC chains

# %%
raw_x = test_theta  
raw_y = np.quantile(post, [0.025, 0.16, 0.5, 0.84, 0.975], axis=1)

# %%
num_bins = 20
splits = np.linspace([5, -1, -1, 0.2], [8, 0.7, 2, 1], num_bins + 1)

x = np.zeros((num_bins, 4))
y = np.zeros((5, num_bins, 4))
for c in range(4):
    bins = np.digitize(raw_x[:,c], splits[:,c]) - 1
    
    for i in range(num_bins):
        mask = (i == bins)
        x[i, c] = raw_x[mask][:,c].mean()
        
        for q, quantile in enumerate(raw_y):
            y[q, i, c] = quantile[mask][:,c].mean()
# Out:
# /tmp/ipykernel_816185/997253202.py:11: RuntimeWarning: Mean of empty slice.
#   x[i, c] = raw_x[mask][:,c].mean()
# /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /tmp/ipykernel_816185/997253202.py:14: RuntimeWarning: Mean of empty slice.
#   y[q, i, c] = quantile[mask][:,c].mean()

# %%
import matplotlib.pyplot as plt


plt.rcParams["text.usetex"] = True

fig, axs = plt.subplots(2,3, figsize=(12,4), sharex="col", gridspec_kw={'hspace': 0,
                                                                        'height_ratios': [3, 1]})

x_titles = ["$\log_{10}(\\rho _0)$", "$\log_{10}(r_s)$", "$\gamma$"]
y_titles = ["$\log_{10}(\hat{\\rho _0})$", "$\log_{10}(\hat{r_s})$", "$\hat \gamma$"]

dom_min = [5, -1, -1, 0.2]
dom_max = [8, 0.7, 2, 1]

# Top plots
for i, ax in enumerate(axs[0, :]):
    index = np.argsort(x[:,i])
    truth = x[:,i][index]
    
    # Median
    sim_median = y[2][:,i][index]
    ax.plot(truth, sim_median, color="blue", label="Median")

    # 68-84
    sim_16 = y[1][:,i][index]
    sim_84 = y[3][:,i][index]
    ax.fill_between(truth, sim_16, sim_84, color=(133 / 256,133/256,247/256, 0.8), label="Mid. 68\%")
    

    # 2.5-97.5
    sim_2_5 = y[0][:,i][index]
    sim_97_5 = y[4][:,i][index]
    ax.fill_between(truth, sim_2_5, sim_97_5, color=(133 / 256,133/256,247/256, 0.5), label="Mid. 95\%")

    # Truth
    true_x = [dom_min[i], dom_max[i]]

    ax.plot(true_x, true_x, color="red", linestyle = "--", label="Truth")

    # ax.set_xlabel(x_titles[i])
    ax.set_ylabel(y_titles[i])
    
    ax.minorticks_on()
    ax.grid(True)

# bottom plots
bottom_y_titles = ["$\Delta \log_{10}(\\rho _0)$", "$\Delta \log_{10}(r_s)$", "$\Delta \gamma$"]
for i, ax in enumerate(axs[1, :]):
    index = np.argsort(x[:,i])
    truth = x[:,i][index]
    # Median
    sim_median = y[2][:,i][index] - truth
    ax.plot(truth, sim_median, color="blue", label="Median")

    # 68-84
    sim_16 = y[1][:,i][index] - truth
    sim_84 = y[3][:,i][index] - truth
    ax.fill_between(truth, sim_16, sim_84, color=(133 / 256,133/256,247/256, 0.8), label="Mid. 68\%")
    

    # 2.5-97.5
    sim_2_5 = y[0][:,i][index] - truth
    sim_97_5 = y[4][:,i][index] - truth
    ax.fill_between(truth, sim_2_5, sim_97_5, color=(133 / 256,133/256,247/256, 0.5), label="Mid. 95\%")

    # Truth
    true_x = [dom_min[i], dom_max[i]]
    true_y = [0,0]

    ax.plot(true_x, true_y, color="red", linestyle = "--", label="Truth")

    ax.set_xlabel(x_titles[i])
    ax.set_ylabel(bottom_y_titles[i])
    
    ax.minorticks_on()
    ax.grid(True)


 
fig.suptitle("Truth v. Predicted DM profile parameters (2000 MCMC samples from 1k galaxies, model trained on 100k galaxies, Pois(100) stars each)", y=1.02)

handles, labels = axs[0,0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc="upper center",
    ncol=4,
    frameon=False,
    bbox_to_anchor=(0.5, 0.98)

)


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Graphing the Posterior

# %%
k = np.random.randint(0, 100)

# %%
# samples =

# %%
fig = corner.corner(
    medians,
    truths=test_theta,
    labels=[r"$\log_{10}(\\rho _0)$", r"\log_{10}(r_s)$", r"$\gamma$"],
    fig=plt.figure(figsize=(8, 8)),
)
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 fig = corner.corner(
#       2     medians,
#       3     truths=test_theta,
#       4     labels=[r"$\log_{10}(\\rho _0)$", r"\log_{10}(r_s)$", r"$\gamma$"],
#       5     fig=plt.figure(figsize=(8, 8)),
#       6 )
#
# ...

# %%
test_theta_raw = np.array(pd.read_csv("./data/training_theta(poisson).csv", header=None))
test_x_raw = np.array(pd.read_csv("./data/training_x(poisson).csv", header=None))

test_theta, index = np.unique(test_theta_raw, axis=0, return_index=True)

index = np.sort(index)[:2001]

test_x = np.split(test_x_raw, index, axis=0)[1:2001]

# %%
# test_x[0].shape
test_theta_raw.shape
# Out:
# (1002445, 4)

# %% [markdown]
# ### Scatter plot

# %%
with open("./model_14/samples_model_14.pkl", "rb") as file:
    post = pickle.load(file)

test_theta_raw = np.array(pd.read_csv("./model_14/test_theta_model_14.csv", header=None))
_, index= np.unique(test_theta_raw, axis=0, return_index=True)

index.sort()

test_theta = test_theta_raw[index][:100]

# %%
x = test_theta  
y = np.quantile(post, [0.025, 0.16, 0.5, 0.84, 0.975], axis=1)

# %%
import matplotlib.pyplot as plt

plt.rcParams["text.usetex"] = True
fig, axs = plt.subplots(1, 3, figsize=(12,4))

x_titles = ["$\log_{10}(\\rho _0)$", "$\log_{10}(r_s)$", "$\gamma$"]
y_titles = ["$\log_{10}(\hat{\\rho _0})$", "$\log_{10}(\hat{r_s})$", "$\hat \gamma$"]

dom_min = [5, -1, -1, 0.2]
dom_max = [8, 0.7, 2, 1]



for i, ax in enumerate(axs):
    # Plot the median  
    
    plt_x = x[:,i]
    plt_y = y[2][:,i]
    
    yerr_68 = np.array([
        plt_y - y[1][:, i],  # Distance down to the 16% quantile
        y[3][:, i] - plt_y   # Distance up to the 84% quantile
    ])

    yerr_95 = np.array([
        plt_y - y[0][:, i],  # Distance down to the 2.5% quantile
        y[4][:, i] - plt_y   # Distance up to the 97.5% quantile
    ])

    ax.scatter(plt_x, plt_y, 
               s=8, 
               c="green",
               zorder=3,
               label="Median")
    ax.errorbar(plt_x, plt_y, 
                yerr=yerr_68, 
                fmt='none', 
                ecolor=(78/255,78/255,222/255), 
                capsize=1, 
                elinewidth=0.5,
                label='Mid. 68\%',
                zorder=2)
    
    ax.errorbar(plt_x, plt_y, 
                yerr=yerr_95, 
                fmt='none', 
                ecolor=(180/255,180/255,237/255), 
                capsize=1, 
                elinewidth=0.5,
                label='Mid. 95\%',
                zorder=1)
    
        # Truth
    true_x = [dom_min[i], dom_max[i]]

    ax.plot(true_x, true_x, color="red", linestyle = "--", label="Truth")
    
    ax.set_ylabel(y_titles[i])
    ax.set_xlabel(x_titles[i])
    
fig.suptitle("Truth v. Predicted DM profile parameters (Model 14)", y=1.02)
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc="upper center",
    ncol=4,
    frameon=False,
    bbox_to_anchor=(0.5, 0.98)

)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Contour plotting

# %% [markdown]
# #### Generate samples

# %%
prior = generate_prior()
log_p_0 = 7
log_r_s = 0
gamma = 1.0
r_star_div_r_s = 0.2

theta = np.expand_dims(np.array([log_p_0, log_r_s, gamma, r_star_div_r_s]), axis=0).astype(np.float32)

# %%
with open('./model/likelihood_estimator(poisson).pkl', 'rb') as file:
    # Load the object from the file
    likelihood_estimator = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 with open('./model/likelihood_estimator(poisson).pkl', 'rb') as file:
#       2     # Load the object from the file
#       3     likelihood_estimator = pickle.load(file)
#
# File /home/tingli/anaconda3/envs/myenv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './model/likelihood_estimator(poisson).pkl'

# %%
def plot_prep(file:str) -> tuple[np.ndarray]:
    samples = np.array(pd.read_csv(file, header=None))
    pos, vel = samples[:,:3], samples[:, 3:]
    r_proj = np.sqrt(pos[:, 0]**2 + pos[:,1]**2)
    v_los = vel[:,2]
    
    return r_proj, v_los

# %%
r_proj, v_los = plot_prep("./Contour/contour_samples_1(own).csv")
a_r_proj, a_v_los = plot_prep("./Contour/contour_samples_1(agama).csv")

r_proj_0, v_los_0 = plot_prep("./Contour/contour_samples_0(own).csv")
a_r_proj_0, a_v_los_0 = plot_prep("./Contour/contour_samples_0(agama).csv")

# %%
def plot_contour(r_proj, v_los, a_r_proj, a_v_los, r_proj_0, v_los_0, a_r_proj_0, a_v_los_0, ax):
    """ calculate and plot the contour of the distribution function in the projected space """
    # calculate the grid
    r_grid = np.linspace(0, 2, 51)
    v_grid = np.linspace(-20, 20, 51)
    R, V = np.meshgrid(r_grid[:-1], v_grid[:-1])

    # number density in the projected space
    Z1, _, _ = np.histogram2d(
        r_proj, v_los, bins=[r_grid, v_grid], density=True)
    Z2, _, _ = np.histogram2d(
        a_r_proj, a_v_los, bins=[r_grid, v_grid], density=True)
    Z3, _, _ = np.histogram2d(
        r_proj_0, v_los_0, bins=[r_grid, v_grid], density=True)
    Z4, _, _ = np.histogram2d(
        a_r_proj_0, a_v_los_0, bins=[r_grid, v_grid], density=True)

    # Find max and min for color bar
    vmax = max(Z1.max(), Z2.max(), Z3.max(), Z4.max())
    levels = np.linspace(0, vmax, 10) 
    
    # plot the contour
    contourf1 = ax[0][0].contourf(
        R, V, Z1.T, levels=levels, cmap="Blues")
    ax[0][1].contourf(
        R, V, Z2.T, levels=levels, cmap="Blues")
    ax[1][0].contourf(
        R, V, Z3.T, levels=levels, cmap="Blues")
    ax[1][1].contourf(
        R, V, Z4.T, levels=levels, cmap="Blues")

    # add colorbar to show the density scale
    cbar = fig.colorbar(contourf1, ax=[ax[0][0], ax[0][1], ax[1][0], ax[1][1]], location='right', fraction=0.03, pad=0.04, format="%.2f")
    cbar.set_label("Number density", fontsize=16, )

    return ax


fig, ax = plt.subplots(2, 2, figsize=(6, 5),
                       sharey="row",
                       sharex="col", 
                       gridspec_kw={'wspace': 0,
                                    'hspace': 0,})



ax = plot_contour(r_proj, v_los, a_r_proj, a_v_los, r_proj_0, v_los_0, a_r_proj_0, a_v_los_0, ax)

num_star_display = 0
# gamma =1
row_1 = ax[0]
# own
row_1[0].scatter(r_proj[:num_star_display], v_los[:num_star_display], s=0.3, color='k', alpha=0.5)
row_1[0].set_xlim(0, 1.5)
row_1[0].set_ylim(-20, 20)
row_1[0].set_ylabel("$\gamma = 1$ \n $v_{los}$ (km/s)", fontsize=16)
row_1[0].set_title("Model", fontsize=12)
row_1[0].set_yticks([ -10, 0, 10])
row_1[0].minorticks_on()

# agama
row_1[1].scatter(a_r_proj[:num_star_display], a_v_los[:num_star_display], s=0.3, color='k', alpha=0.5)
row_1[1].set_xlim(0, 1.5)
row_1[1].set_ylim(-20, 20)
row_1[1].set_title("Agama", fontsize=12)
row_1[1].minorticks_on()


# gamma = 0
row_2 = ax[1]

#own
row_2[0].scatter(r_proj_0[:num_star_display], v_los_0[:num_star_display], s=0.3, color='k', alpha=0.5)
row_2[0].set_xlim(0, 1.5)
row_2[0].set_ylim(-20, 20)
row_2[0].set_xlabel(r"$R$ (kpc)", fontsize=16)
row_2[0].set_ylabel("$\gamma = 0$ \n $v_{los}$ (km/s)", fontsize=16)
row_2[0].set_xticks([ 0.5, 1.0])
row_2[0].set_yticks([ -10, 0, 10])
row_2[0].minorticks_on()

# agama
row_2[1].scatter(a_r_proj_0[:num_star_display], a_v_los_0[:num_star_display], s=0.3, color='k', alpha=0.5)
row_2[1].set_xlim(0, 1.5)
row_2[1].set_ylim(-20, 20)
row_2[1].set_xlabel(r"$R$ (kpc)", fontsize=16)
row_2[1].set_xticks([ 0.5, 1.0])
row_2[1].minorticks_on()


fig.suptitle(
    r"Contour: $r_s={:.1f} \ \mathrm{{kpc}}; \rho_s={:.1e} \ \mathrm{{M_\odot/kpc^3}}$".format(
        10 ** log_r_s, 10 ** log_p_0), fontsize=16)

    
    
plt.show()

# %% [markdown]
# ### Contour v2

# %% [markdown]
# ##### generate

# %%
with open("./model_15/inference_model_15_core.pkl", "rb") as file:
    inference = pickle.load(file)
galaxy = np.expand_dims(np.array([7, 0, 0, 0.2]), axis=0).astype(np.float32)
df = inference._neural_net.sample(100_000, context=galaxy).squeeze().detach().numpy()
pd.DataFrame(df).to_csv("./model_15/contour_samples_model_15_core.csv", header=None, index=None)

# %% [markdown]
# ##### plot

# %%
prior = generate_prior()
log_p_0 = 7
log_r_s = 0
gamma = 1
r_star_div_r_s = 0.2

theta = np.expand_dims(np.array([log_p_0, log_r_s, gamma, r_star_div_r_s]), axis=0).astype(np.float32)

# %%
def plot_prep(file:str, dim:int = 6, standardization:str = None) -> tuple[np.ndarray]:
    samples = np.array(pd.read_csv(file, header=None))
    if standardization is not None:
        x = standardize(np.array(pd.read_csv(standardization, header=None)))
        samples = samples * x[2] + x[1]
        
    if dim == 6:
        pos, vel = samples[:,:3], samples[:, 3:]
        r_proj = np.sqrt(pos[:, 0]**2 + pos[:,1]**2)
        v_los = vel[:,2]
    elif dim == 3:
        r_proj = np.sqrt(samples[:,0] ** 2 + samples[:,1] ** 2)
        v_los = samples[:, -1]
    elif dim == 2:
        r_proj = samples[:,0]
        v_los = samples[:,1]
    
    return r_proj, v_los

# %%
r_proj, v_los = plot_prep("./model_14/contour_samples_model_14_cusp.csv", 
                          dim=3,
                          standardization="./model_14/train_x_model_14.csv")
a_r_proj, a_v_los = plot_prep("./Contour/contour_samples_1(agama).csv")

r_proj_0, v_los_0 = plot_prep("./model_14/contour_samples_model_14_core.csv",
                              dim=3,
                              standardization="./model_14/train_x_model_14.csv")
a_r_proj_0, a_v_los_0 = plot_prep("./Contour/contour_samples_0(agama).csv")

# %%
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D

def plot_contour(r_proj, v_los, a_r_proj, a_v_los, r_proj_0, v_los_0, a_r_proj_0, a_v_los_0, ax):
    """ calculate and plot the contour of the distribution function in the projected space """
    # calculate the grid
    r_grid = np.linspace(0, 2, 51)
    v_grid = np.linspace(-20, 20, 51)
    R, V = np.meshgrid(r_grid[:-1], v_grid[:-1])

    # number density in the projected space
    
    Z1, _, _ = np.histogram2d(
        r_proj, v_los, bins=[r_grid, v_grid], density=True)
    Z2, _, _ = np.histogram2d(
        a_r_proj, a_v_los, bins=[r_grid, v_grid], density=True)
    Z3, _, _ = np.histogram2d(
        r_proj_0, v_los_0, bins=[r_grid, v_grid], density=True)
    Z4, _, _ = np.histogram2d(
        a_r_proj_0, a_v_los_0, bins=[r_grid, v_grid], density=True)

    # # Find max and min for color bar
    # vmax = max(Z1.max(), Z2.max(), Z3.max(), Z4.max())
    # levels = np.linspace(0, vmax, 10) 
    
    # plot the contour
    agama_colour = (237/255, 111/255, 132/255)
    model_colour = "Blues"
    contourf1 = ax[0].contourf(
        R, V, Z1.T, levels=np.linspace(0, Z1.max(), 10), cmap=model_colour, alpha=0.8)
    ax[0].contour(
        R, V, Z2.T, levels=np.linspace(0, Z2.max(), 10), colors=[agama_colour], linewidths=1.2)
    ax[1].contourf(
        R, V, Z3.T, levels=np.linspace(0, Z3.max(), 10), cmap=model_colour, alpha=0.8)
    ax[1].contour(
        R, V, Z4.T, levels=np.linspace(0, Z4.max(), 10), colors=[agama_colour], linewidths=1.2)

    # add colorbar to show the density scale
    # cbar = fig.colorbar(contourf1, ax=[ax[0], ax[1]], location='right', fraction=0.03, pad=0.04, format="%.2f")
    # cbar.set_label("Density", fontsize=16, )

    return ax


fig, ax = plt.subplots(1, 2, figsize=(12, 5),
                       sharey="row",
                       gridspec_kw={'wspace': 0,})



ax = plot_contour(r_proj, v_los, a_r_proj, a_v_los, r_proj_0, v_los_0, a_r_proj_0, a_v_los_0, ax)

# Cusp, gamma = 1
ax[0].set_xlim(0, 0.6)
ax[0].set_ylim(-10, 10)
ax[0].set_title("$\gamma = 1$", fontsize=16)
ax[0].set_ylabel("$v_{los}$ (km/s)", fontsize=12)
ax[0].set_xlabel(r"$R$ (kpc)", fontsize=12)
ax[0].set_yticks([ -5, 0, 5])
ax[0].set_xticks([ 0.2, 0.4])
ax[0].minorticks_on()

# Cusp, gamma = 0
ax[1].set_xlim(0, 0.6)
ax[1].set_ylim(-10, 10)
ax[1].set_title("$\gamma = 0$", fontsize=16)
ax[1].set_xlabel(r"$R$ (kpc)", fontsize=12)
ax[1].set_yticks([ -5, 0, 5])
ax[1].set_xticks([ 0.2, 0.4])
ax[1].minorticks_on()

# Add a Legend to the first plot to explain the lines vs fill
model_patch = mpatches.Patch(color='#4A90E2', alpha=0.7, label='Model (NLE)')
agama_line = Line2D([0], [0], color=(237/255, 111/255, 132/255), lw=2, label='Agama (Truth)')
ax[1].legend(handles=[model_patch, agama_line], loc='upper right', fontsize=10, frameon=True)

fig.suptitle(
    r"Contour: Model 14 - $r_s={:.1f} \ \mathrm{{kpc}}; \rho_s={:.1e} \ \mathrm{{M_\odot/kpc^3}}$".format(
        10 ** log_r_s, 10 ** log_p_0), fontsize=16)

    
    
plt.show()

# %% [markdown]
# ### Metric

# %% [markdown]
# #### Hellinger

# %%
def hellinger_distance(r_proj, v_los, a_r_proj, a_v_los, resolution = 50):
    """ calculate and plot the contour of the distribution function in the projected space
    
    params
        - r_proj: projected radius simualted by model
        - v_los: velocity simualted by model
        - a_r_proj: projected radius simualted by Agama
        - a_v_los: velocity simualted by Agama
        - resolution: the number of grids the data point can land on
        
    """
    # calculate the grid
    r_grid = np.linspace(0, 2, resolution + 1)
    v_grid = np.linspace(-20, 20, resolution + 1)

    # number density in the projected space
    Z1, _, _ = np.histogram2d(
        r_proj, v_los, bins=[r_grid, v_grid], density=True)
    Z2, _, _ = np.histogram2d(
        a_r_proj, a_v_los, bins=[r_grid, v_grid], density=True)
    
    sum1 = np.sum(Z1)
    sum2 = np.sum(Z2)
    
    Z1 = Z1 / sum1 if sum1 > 0 else Z1
    Z2 = Z2 / sum2 if sum2 > 0 else Z2
    
    return np.sqrt(0.5 * np.sum((np.sqrt(Z1) - np.sqrt(Z2))**2))

# %%
r_proj, v_los = plot_prep("./Contour/contour_samples_1(own).csv")
a_r_proj, a_v_los = plot_prep("./Contour/contour_samples_1(agama).csv")

r_proj_0, v_los_0 = plot_prep("./Contour/contour_samples_0(own).csv")
a_r_proj_0, a_v_los_0 = plot_prep("./Contour/contour_samples_0(agama).csv")

# %%
r_proj, v_los = plot_prep("./model 9/contour_samples_model_9_cusp.csv")
a_r_proj, a_v_los = plot_prep("./Contour/contour_samples_1(agama).csv")

r_proj_0, v_los_0 = plot_prep("./model 9/contour_samples_model_9_core_v2.csv")
a_r_proj_0, a_v_los_0 = plot_prep("./Contour/contour_samples_0(agama).csv")

# %%
hellinger_distance(r_proj_0, v_los_0, a_r_proj_0, a_v_los_0, resolution = 100)
# Out:
# 0.41896126819856494

# %%
hellinger_distance(r_proj, v_los, a_r_proj, a_v_los, resolution = 100)
# Out:
# 0.14799774185537296

# %% [markdown]
# #### Earth-mover's or Wasserstein

# %%
r_proj, v_los = plot_prep("./model 9/contour_samples_model_9_cusp.csv")
a_r_proj, a_v_los = plot_prep("./Contour/contour_samples_1(agama).csv")

r_proj_0, v_los_0 = plot_prep("./model 9/contour_samples_model_9_core_v2.csv")
a_r_proj_0, a_v_los_0 = plot_prep("./Contour/contour_samples_0(agama).csv")

# %%
model_dist = np.zeros((r_proj.shape[0],2))
model_dist[:,0] = r_proj
model_dist[:,1] = v_los

agama_dist = np.zeros((r_proj.shape[0],2))
agama_dist[:,0] = a_r_proj
agama_dist[:,1] = a_v_los

# %%
wasserstein_distance_nd(model_dist[:1000], agama_dist[:1000])
# Out:
# 0.48489677117765784

# %% [markdown]
# ### Mass and Density profile

# %%
log_p_0 = 7
log_r_s = 0
# gamma = 0
r_star_div_r_s = 0.2

r_star = r_star_div_r_s * 10 ** log_r_s
# theta = torch.tensor(np.array([[log_p_0, log_r_s, gamma, r_star_div_r_s]]))

# %%
cored_params = np.array(pd.read_csv("./model 9/mass_density_samples_core_model_9.csv", header=None))
cusp_params = np.array(pd.read_csv("./model 9/mass_density_samples_cusp_model_9.csv", header=None))

# %%
def density(r: np.ndarray, 
            log_p_0: float, 
            log_r_s: float,
            gamma: float) -> np.ndarray:
    """
    Calculate density using GNFW profile as a function of r
    """
    p_0 = 10 ** log_p_0
    r_s = 10 ** log_r_s

    rho = p_0 * (r / r_s) ** -gamma * (1 + r / r_s) ** -(3-gamma)
    
    return rho

# %%
def mass(r: np.ndarray, 
        log_p_0: float, 
        log_r_s: float,
        gamma: float) -> np.ndarray:
    """
    Calculate the mass as a function of r
    """
    
    out = []
    for n in r:
        I = integrate.quad(lambda t: 4 * np.pi * t * t * density(t, log_p_0, log_r_s, gamma), 0, n)[0]
        out.append(I)
    
    return np.array(out)

# %%
def prep_y_density(r_div_r_star:float, i:int, post) -> np.ndarray:
    r =  r_div_r_star * (post[i][3] * 10 ** post[i][1])
    y = density(r, post[i][0], post[i][1], post[i][2])
    return y

def prep_y_mass(r_div_r_star:float, i:int, post) -> np.ndarray:
    r =  r_div_r_star * (post[i][3] * 10 ** post[i][1])
    y = mass(r, post[i][0], post[i][1], post[i][2])
    return y

# %%
plt.rcParams["text.usetex"] = True
fig, axs = plt.subplots(2, 2, 
                       figsize=(8, 8),
                       sharex="col", 
                       sharey="row",
                       gridspec_kw={'hspace': 0,
                                    'wspace': 0,})

xlim = 2
# Cored profile, gamma = 0
gamma = 0
post = np.quantile(cored_params, [0.025, 0.16, 0.5, 0.84, 0.975], axis=0)

# Density
# x
x = r_div_r_star = np.logspace(-xlim, xlim, 1000)
# y
# Truth
r =  r_div_r_star * r_star
y = density(r, log_p_0, log_r_s, gamma)
axs[0][0].plot(np.log10(x), np.log10(y), color="red", linestyle = "--", label="Truth")

# Median
y = prep_y_density(r_div_r_star, 2, post)
axs[0][0].plot(np.log10(x), np.log10(y), color=(8/255, 2/255, 134/255), label="Median")

#16-84
y_16 = prep_y_density(r_div_r_star, 1, post)
y_84 = prep_y_density(r_div_r_star, 3, post)
axs[0][0].fill_between(np.log10(x), np.log10(y_16), np.log10(y_84), color=(133/255, 133/255, 247/255, 0.8), label="Mid 68%")

#16-84
y_2_5 = prep_y_density(r_div_r_star, 0, post)
y_97_5 = prep_y_density(r_div_r_star, 4, post)
axs[0][0].fill_between(np.log10(x), np.log10(y_2_5), np.log10(y_97_5), color=(133/255, 133/255, 247/255, 0.5), label="Mid 95%")

# Aesthetics
axs[0][0].set_ylabel(r"$\log_{10} \rho\ [M_\odot / \mathrm{kpc}^3]$")
axs[0][0].xaxis.set_label_position('top')
axs[0][0].set_xlabel(r"Cored Profile: $\gamma = 0$", fontweight="bold")

axs[0][0].minorticks_on()
axs[0][0].grid(True)

# Mass
# y
# Truth
r =  r_div_r_star * r_star
y = mass(r, log_p_0, log_r_s, gamma)
axs[1][0].plot(np.log10(x), np.log10(y), color="red", linestyle = "--", label="Truth")

# Median
y = prep_y_mass(r_div_r_star, 2, post)
axs[1][0].plot(np.log10(x), np.log10(y), color=(8/255, 2/255, 134/255), label="Median")

#16-84
y_16 = prep_y_mass(r_div_r_star, 1, post)
y_84 = prep_y_mass(r_div_r_star, 3, post)
axs[1][0].fill_between(np.log10(x), np.log10(y_16), np.log10(y_84), color=(133/255, 133/255, 247/255, 0.8), label="Mid 68%")

#16-84
y_2_5 = prep_y_mass(r_div_r_star, 0, post)
y_97_5 = prep_y_mass(r_div_r_star, 4, post)
axs[1][0].fill_between(np.log10(x), np.log10(y_2_5), np.log10(y_97_5), color=(133/255, 133/255, 247/255, 0.5), label="Mid 95%")

# Aesthetics
axs[1][0].set_ylabel(r"$\log_{10} M / M_\odot$")
axs[1][0].set_xlabel(r"$\log _{10} (r/r_*)$")

axs[1][0].minorticks_on()
axs[1][0].grid(True)





# Cuspy profile: gamma = 1
gamma = 1
post = np.quantile(cusp_params, [0.025, 0.16, 0.5, 0.84, 0.975], axis=0)

# Density
# x
x = r_div_r_star = np.logspace(-xlim, xlim, 1000)
# y
# Truth
r =  r_div_r_star * r_star
y = density(r, log_p_0, log_r_s, gamma)
axs[0][1].plot(np.log10(x), np.log10(y), color="red", linestyle = "--", label="Truth")

# Median
y = prep_y_density(r_div_r_star, 2, post)
axs[0][1].plot(np.log10(x), np.log10(y), color=(8/255, 2/255, 134/255), label="Median")

#16-84
y_16 = prep_y_density(r_div_r_star, 1, post)
y_84 = prep_y_density(r_div_r_star, 3, post)
axs[0][1].fill_between(np.log10(x), np.log10(y_16), np.log10(y_84), color=(133/255, 133/255, 247/255, 0.8), label="Mid 68%")

#16-84
y_2_5 = prep_y_density(r_div_r_star, 0, post)
y_97_5 = prep_y_density(r_div_r_star, 4, post)
axs[0][1].fill_between(np.log10(x), np.log10(y_2_5), np.log10(y_97_5), color=(133/255, 133/255, 247/255, 0.5), label="Mid 95%")

# Aesthetics
axs[0][1].xaxis.set_label_position('top')
axs[0][1].set_xlabel(r"Cuspy Profile: $\gamma = 1$", fontweight="bold")
axs[0][1].legend()

axs[0][1].minorticks_on()
axs[0][1].grid(True)

# Mass
# y
# Truth
r =  r_div_r_star * r_star
y = mass(r, log_p_0, log_r_s, gamma)
axs[1][1].plot(np.log10(x), np.log10(y), color="red", linestyle = "--", label="Truth")

# Median
y = prep_y_mass(r_div_r_star, 2, post)
axs[1][1].plot(np.log10(x), np.log10(y), color=(8/255, 2/255, 134/255), label="Median")

#16-84
y_16 = prep_y_mass(r_div_r_star, 1, post)
y_84 = prep_y_mass(r_div_r_star, 3, post)
axs[1][1].fill_between(np.log10(x), np.log10(y_16), np.log10(y_84), color=(133/255, 133/255, 247/255, 0.8), label="Mid 68\%")

#16-84
y_2_5 = prep_y_mass(r_div_r_star, 0, post)
y_97_5 = prep_y_mass(r_div_r_star, 4, post)
axs[1][1].fill_between(np.log10(x), np.log10(y_2_5), np.log10(y_97_5), color=(133/255, 133/255, 247/255, 0.5), label="Mid 95\%")

# Aesthetics
axs[1][1].set_xlabel(r"$\log _{10} (r/r_*)$")
axs[1][1].minorticks_on()
axs[1][1].grid(True)


fig.suptitle("Recovered Density and Mass Profile of a Sample Galaxy (Model 9) \n$\log_{10}(\\rho _0)=7,\ \log_{10}(r_s) = 0,\ r_* / r_s = 0.2$")

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Mass Density Profile Attempt 2

# %%
log_p_0 = 7
log_r_s = 0
# gamma = 0
r_star_div_r_s = 0.2

r_star = r_star_div_r_s * 10 ** log_r_s

# cored_params = np.array(pd.read_csv("./model 3/mass_density_samples_core_model_3_s1000.csv", header=None))
# cusp_params = np.array(pd.read_csv("./model 3/mass_density_samples_cusp_model_3_s1000.csv", header=None))

# cored_params = np.array(pd.read_csv("./Mass density profile/mass_density_profile_1k_32(0).csv", header=None))
# cusp_params = np.array(pd.read_csv("./Mass density profile/mass_density_profile_1k_32(1).csv", header=None))

# round = 5
cored_params = np.array(pd.read_csv(f"./model_14/mass_density_samples_model_14_core_s1000.csv", header=None))
cusp_params = np.array(pd.read_csv(f"./model_14/mass_density_samples_model_14_cusp_s1000.csv", header=None))

# cored_params = np.array(pd.read_csv(f"./Mass density profile/mass_density_samples_model_13_1_core.csv", header=None))
# cusp_params = np.array(pd.read_csv(f"./model_13_1/mass_density_samples_model_13_1_cusp.csv", header=None))

# %%
def density(log_r_div_rstar: float, 
            samples: np.ndarray) -> np.ndarray:
    """
    Calculate density using GNFW profile as a function of r
    """
    p_0 = 10 ** samples[:,0]
    r_s = 10 ** samples[:,1]
    gamma = samples[:,2]
    r = 10 ** log_r_div_rstar * (samples[:,3] * r_s)

    rho = p_0 * (r / r_s) ** -gamma * (1 + r / r_s) ** -(3-gamma)
    
    return np.log10(rho)

def density_single(r:float,
                   samples:np.ndarray):
    """
    Calculate density using GNFW profile as a function of r
    """
    p_0 = 10 ** samples[0]
    r_s = 10 ** samples[1]
    gamma = samples[2]
    # r = 10 ** log_r_div_rstar * (samples[3] * r_s)

    rho = p_0 * (r / r_s) ** -gamma * (1 + r / r_s) ** -(3-gamma)
    
    return rho

# def mass(log_r_div_rstar: float, 
#         samples:np.ndarray) -> np.ndarray:
#     """
#     Calculate the mass as a function of r
#     """
#     out = []
#     for row in samples:
#         r = 10 ** log_r_div_rstar * (row[3] * 10 ** row[1])
#         I = integrate.quad(lambda t: 4 * np.pi * t * t * density_single(t, row), 0, r)[0]
#         out.append(I)
#     return np.log10(np.array(out))



def mass(x, samples):
    
    out = np.zeros((samples.shape[0], x.shape[0]))
    for i, row in enumerate(samples):
        r = 10 ** x * (row[3] * 10 ** row[1])
        y = 4 * np.pi * r * r * density_single(r, row)
        
        M_0 = integrate.quad(lambda t: 4 * np.pi * t * t * density_single(t, row), 0, r[0])[0]
        I = integrate.cumulative_trapezoid(y, r) + M_0
        out[i,0] = np.log10(M_0)
        out[i,1:] = np.log10(I)
    return out

# %%
def prep_y(x, params):

    quantiles = [0.025, 0.16, 0.50, 0.84, 0.975]

    y_density = np.zeros((x.shape[0], 5))
    for i, log_r_rstar in enumerate(x):
        y = density(log_r_rstar, params)
        y_density[i] = np.quantile(y, quantiles)
    
    # y_mass = np.zeros((x.shape[0], 5))
    # for i, log_r_rstar in enumerate(x):
    #     y = mass(log_r_rstar, params)
    #     y_mass[i] = np.quantile(y, quantiles)
    
    raw_mass = mass(x, params)
    y_mass = np.quantile(raw_mass, quantiles, axis=0).T
    
    return y_density, y_mass

# %%
def prep_truth(x, theta):
    true_density = []
    for log_r_rstar in x:
        true_density.append(density(log_r_rstar, np.array([theta])))
    
    true_mass = mass(x, np.array([theta]))
    return np.array(true_density).squeeze(), np.array(true_mass).squeeze()

# %%
plt.rcParams["text.usetex"] = True
fig, axs = plt.subplots(2, 2, 
                       figsize=(8, 8),
                       sharex="col", 
                       sharey="row",
                       gridspec_kw={'hspace': 0,
                                    'wspace': 0,})

xlim = 2
resolution = 1000
x = np.linspace(-xlim, xlim, resolution) # log_r_div_r_star

# Cored profile
# Density
# y
y_density, y_mass = prep_y(x, cored_params)
#2.5-97.5
axs[0][0].fill_between(x, y_density[:,0], y_density[:,4], color=(133/255, 133/255, 247/255, 0.5), label="Mid 95%")

#16-84
axs[0][0].fill_between(x, y_density[:,1], y_density[:,3], color=(133/255, 133/255, 247/255, 0.8), label="Mid 68%")

# Median
axs[0][0].plot(x, y_density[:,2], color=(8/255, 2/255, 134/255), label="Median")

# Truth
true_density, true_mass = prep_truth(x, [log_p_0, log_r_s, 0, r_star_div_r_s])
axs[0][0].plot(x, true_density, color="red", linestyle = "--", label="Truth")



# Aesthetics
axs[0][0].set_ylabel(r"$\log_{10} \rho\ [M_\odot / \mathrm{kpc}^3]$")
axs[0][0].xaxis.set_label_position('top')
axs[0][0].set_xlabel(r"Cored Profile: $\gamma = 0$", fontweight="bold")

axs[0][0].minorticks_on()
axs[0][0].grid(True)

# Mass
# y
#2.5-97.5
axs[1][0].fill_between(x, y_mass[:,0], y_mass[:,4], color=(133/255, 133/255, 247/255, 0.5), label="Mid 95%")

#16-84
axs[1][0].fill_between(x, y_mass[:,1], y_mass[:,3], color=(133/255, 133/255, 247/255, 0.8), label="Mid 68%")

# Median
axs[1][0].plot(x, y_mass[:,2], color=(8/255, 2/255, 134/255), label="Median")


# Truth
axs[1][0].plot(x, true_mass, color="red", linestyle = "--", label="Truth")

# Aesthetics
axs[1][0].set_ylabel(r"$\log_{10} M / M_\odot$")
axs[1][0].set_xlabel(r"$\log _{10} (r/r_*)$")

axs[1][0].minorticks_on()
axs[1][0].grid(True)





# Cuspy profile: gamma = 1
y_density, y_mass = prep_y(x, cusp_params)
true_density, true_mass = prep_truth(x, [log_p_0, log_r_s, 1, r_star_div_r_s])

# Density
#2.5-97.5
axs[0][1].fill_between(x, y_density[:,0], y_density[:,4], color=(133/255, 133/255, 247/255, 0.5), label="Mid 95%")

#16-84
axs[0][1].fill_between(x, y_density[:,1], y_density[:,3], color=(133/255, 133/255, 247/255, 0.8), label="Mid 68%")

# Median
axs[0][1].plot(x, y_density[:,2], color=(8/255, 2/255, 134/255), label="Median")

# Truth
axs[0][1].plot(x, true_density, color="red", linestyle = "--", label="Truth")

# Aesthetics
axs[0][1].xaxis.set_label_position('top')
axs[0][1].set_xlabel(r"Cuspy Profile: $\gamma = 1$", fontweight="bold")
axs[0][1].legend()

axs[0][1].minorticks_on()
axs[0][1].grid(True)

# Mass
# y
#2.5-97.5
axs[1][1].fill_between(x, y_mass[:,0], y_mass[:,4], color=(133/255, 133/255, 247/255, 0.5), label="Mid 95\%")

#16-84
axs[1][1].fill_between(x, y_mass[:,1], y_mass[:,3], color=(133/255, 133/255, 247/255, 0.8), label="Mid 68\%")

# Median
axs[1][1].plot(x, y_mass[:,2], color=(8/255, 2/255, 134/255), label="Median")

# Truth
axs[1][1].plot(x, true_mass, color="red", linestyle = "--", label="Truth")

# Aesthetics
axs[1][1].set_xlabel(r"$\log _{10} (r/r_*)$")
axs[1][1].minorticks_on()
axs[1][1].grid(True)


fig.suptitle("Recovered Density and Mass Profile of a Sample Galaxy (Model 14, 1k stars)" + "\n$\log_{10}(\\rho _0)=7,\ \log_{10}(r_s) = 0,\ r_* / r_s = 0.2$")

fig.tight_layout()
plt.show()

# %%
y_mass
# Out:
# array([[1.24526703, 1.51689883, 1.84251069, 2.108358  , 2.38337659],
#        [1.25606766, 1.52703766, 1.85207282, 2.11708835, 2.39152506],
#        [1.26686793, 1.53717616, 1.86161139, 2.12581853, 2.39967339],
#        ...,
#        [8.19411163, 8.26597738, 8.34472091, 8.43284967, 8.52003401],
#        [8.19556307, 8.26747852, 8.34626805, 8.43451022, 8.52170278],
#        [8.19701039, 8.26897851, 8.34783101, 8.43623926, 8.52336638]])
